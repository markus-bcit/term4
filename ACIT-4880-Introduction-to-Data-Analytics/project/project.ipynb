# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('NYC_property_sales.csv')

# %% [markdown]
# 1. How does the distribution of average household expenditure vary across different expenditure categories?

# %%
data[(data['residential_units'].isin([1, 2, 3])) | (data['apartment_number'].notnull())]
# Out:
#              borough neighborhood  building_class_category  \
# 0              Bronx     Bathgate  01 One Family Dwellings
# 1              Bronx     Bathgate  01 One Family Dwellings
# 2              Bronx     Bathgate  01 One Family Dwellings
# 3              Bronx     Bathgate  01 One Family Dwellings
# 4              Bronx     Bathgate  01 One Family Dwellings
# ...              ...          ...                      ...
# 38172  Staten Island      Woodrow  02 Two Family Dwellings
# 38173  Staten Island      Woodrow  02 Two Family Dwellings
# 38174  Staten Island      Woodrow  02 Two Family Dwellings
# 38175  Staten Island      Woodrow  02 Two Family Dwellings
# 38176  Staten Island      Woodrow  02 Two Family Dwellings
#
#       tax_class_at_present  block  lot building_class_at_present  \
# 0                        1   3030   62                        A1
# 1                        1   3030   70                        A1
# ...

# %%
data['building_class_category'] = data['building_class_category'].str.split(' ').str[0]
data
# Out:
#              borough neighborhood building_class_category  \
# 0              Bronx     Bathgate                      01
# 1              Bronx     Bathgate                      01
# 2              Bronx     Bathgate                      01
# 3              Bronx     Bathgate                      01
# 4              Bronx     Bathgate                      01
# ...              ...          ...                     ...
# 38172  Staten Island      Woodrow                      02
# 38173  Staten Island      Woodrow                      02
# 38174  Staten Island      Woodrow                      02
# 38175  Staten Island      Woodrow                      02
# 38176  Staten Island      Woodrow                      02
#
#       tax_class_at_present  block  lot building_class_at_present  \
# 0                        1   3030   62                        A1
# 1                        1   3030   70                        A1
# 2                        1   3039   63                        A1
# ...

# %%
data['price_per_sqft'] = data['sale_price'] / data['gross_square_feet']
data
# Out:
#              borough neighborhood building_class_category  \
# 0              Bronx     Bathgate                      01
# 1              Bronx     Bathgate                      01
# 2              Bronx     Bathgate                      01
# 3              Bronx     Bathgate                      01
# 4              Bronx     Bathgate                      01
# ...              ...          ...                     ...
# 38172  Staten Island      Woodrow                      02
# 38173  Staten Island      Woodrow                      02
# 38174  Staten Island      Woodrow                      02
# 38175  Staten Island      Woodrow                      02
# 38176  Staten Island      Woodrow                      02
#
#       tax_class_at_present  block  lot building_class_at_present  \
# 0                        1   3030   62                        A1
# 1                        1   3030   70                        A1
# 2                        1   3039   63                        A1
# ...
